# %%
from glidergun import stack

stack("input/LC08_L2SP_197021_20220324_20220330_02_T1_SR_B4.TIF",
      "input/LC08_L2SP_197021_20220324_20220330_02_T1_SR_B3.TIF",
      "input/LC08_L2SP_197021_20220324_20220330_02_T1_SR_B2.TIF")
# Out:
# /home/vscode/.local/lib/python3.12/site-packages/glidergun/_ipython.py:32: RuntimeWarning: invalid value encountered in cast
#   plt.imshow(np.dstack([*[np.asanyarray(g, "uint8") for g in rgb], alpha]))
# image: 2010x2033 float32 | crs: EPSG:32632 | cell: 120.0, 120.0 | count: 3 | rgb: (1, 2, 3)
