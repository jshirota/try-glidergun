# %%
from glidergun import grid

dem = grid("input/n55_e008_1arc_v3.bil")

dem, dem * (dem > 20), -dem
# Out:
# (image: 1801x3601 float32 | range: -28.000~101.000 | mean: 11.566 | std: 11.566 | crs: EPSG:4326 | cell: 0.000555555555555556, 0.000277777777777778,
#  image: 1801x3601 float32 | range: 0.000~101.000 | mean: 8.644 | std: 8.644 | crs: EPSG:4326 | cell: 0.000555555555555556, 0.000277777777777778,
#  image: 1801x3601 float32 | range: -101.000~28.000 | mean: -11.566 | std: -11.566 | crs: EPSG:4326 | cell: 0.000555555555555556, 0.000277777777777778)
