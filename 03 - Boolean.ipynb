# %%
from glidergun import grid

dem = grid("input/n55_e008_1arc_v3.bil")

dem > 10
# Out:
# image: 1801x3601 bool | range: 0~1 | mean: 0 | std: 0 | crs: EPSG:4326 | cell: 0.000555555555555556, 0.000277777777777778
