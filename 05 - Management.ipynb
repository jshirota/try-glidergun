# %%
from glidergun import grid, mosaic

dem1 = grid("input/n55_e008_1arc_v3.bil")
dem2 = grid("input/n55_e009_1arc_v3.bil")

geographic = mosaic(dem1, dem2).resample(0.04)
web_mercator = geographic.project(3857)

geographic, web_mercator
# Out:
# (image: 50x25 float32 | range: -4.000~162.000 | mean: 26.582 | std: 26.582 | crs: EPSG:4326 | cell: 0.04, 0.04,
#  image: 42x37 float32 | range: -4.000~162.000 | mean: 26.282 | std: 26.282 | crs: EPSG:3857 | cell: 5312.629828432797, 5312.629828432797)
