# %%
from glidergun import grid

dem = grid("input/n55_e008_1arc_v3.bil")

dem.set_nan(dem <= 0)
# Out:
# image: 1801x3601 float32 | range: 1.000~101.000 | mean: 20.524 | std: 20.524 | crs: EPSG:4326 | cell: 0.000555555555555556, 0.000277777777777778
