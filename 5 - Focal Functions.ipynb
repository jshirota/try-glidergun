# %%
from glidergun import grid

dem = grid("input/n55_e008_1arc_v3.bil").resample(0.04)

dem, dem.focal_mean(1), dem.focal_mean(2), dem.focal_mean(3), dem.focal_mean(4)
# Out:
# (image: 25x25 float32 | range: -4.000~75.000 | mean: 11.718 | std: 11.718 | crs: EPSG:4326 | cell: 0.04, 0.04,
#  image: 25x25 float32 | range: -2.000~58.167 | mean: 11.647 | std: 11.647 | crs: EPSG:4326 | cell: 0.04, 0.04,
#  image: 25x25 float32 | range: -1.800~51.400 | mean: 11.636 | std: 11.636 | crs: EPSG:4326 | cell: 0.04, 0.04,
#  image: 25x25 float32 | range: -0.821~45.036 | mean: 11.619 | std: 11.619 | crs: EPSG:4326 | cell: 0.04, 0.04,
#  image: 25x25 float32 | range: -0.300~41.133 | mean: 11.615 | std: 11.615 | crs: EPSG:4326 | cell: 0.04, 0.04)
