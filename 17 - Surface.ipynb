# %%
from glidergun import grid

dem = grid("input/n55_e008_1arc_v3.bil")

dem.aspect()
# Out:
# image: 1801x3601 float32 | range: -3.142~3.083 | mean: -0.203 | std: -0.203 | crs: EPSG:4326 | cell: 0.000555555555555556, 0.000277777777777778
